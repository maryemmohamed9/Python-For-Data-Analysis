# %% [markdown]
# <a href="https://colab.research.google.com/github/maryemmohamed9/Python-For-Data-Analysis/blob/main/Customer_Churn_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read Data

# %%
import numpy as np
import pandas as pd
df=pd.read_excel('02 Customer Churn-Dataset.xlsx')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Data Exploration

# %%
df.shape
# Out:
# (7043, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df.MultipleLines.unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df.TotalCharges.unique()
# Out:
# array([29.85, 1889.5, 108.15, ..., 346.45, 306.6, 6844.5], dtype=object)

# %%
df.tenure.unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39])

# %%
df.SeniorCitizen.unique()
# Out:
# array([0, 1])

# %%
df.numAdminTickets.unique()
# Out:
# array([0, 1, 5, 2, 4, 3])

# %%
df.numTechTickets.unique()
# Out:
# array([0, 3, 2, 4, 1, 6, 5, 7, 8, 9])

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# numAdminTickets     0
# numTechTickets      0
# Churn               0
# dtype: int64

# %% [markdown]
# # Handling Errors

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].fillna(0, inplace=True)
# Out:
# <ipython-input-63-e88c90ddca19>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df['MultipleLines']=df['MultipleLines'].replace('No phone service','No')

# %%
df.customerID.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Ask Questions
#
# > max monthly charge
#
# > number of customers
#
# > sum of total charges
#
# > number of customers by payment method
#
# > total charges by payment method
#
# > number of customers by gender
#
# > number of customers by internet service
#
# > total charge by internet service
#
# > total charge and number of customers by contract type
#
# >

# %%
df['MonthlyCharges'].max()
# Out:
# 118.75

# %%
CustomerNo=df['customerID'].count()
CustomerNo
# Out:
# 7043

# %%
TotalCharges =sum(df['TotalCharges'])
TotalCharges
# Out:
# 16056168.700000027

# %%
df.groupby('PaymentMethod')['customerID'].count()
# Out:
# PaymentMethod
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Electronic check             2365
# Mailed check                 1612
# Name: customerID, dtype: int64

# %%
df.groupby('PaymentMethod')['TotalCharges'].sum().sort_values(ascending=False)
# Out:
# PaymentMethod
# Electronic check             4944903.25
# Bank transfer (automatic)    4748279.90
# Credit card (automatic)      4671593.35
# Mailed check                 1691392.20
# Name: TotalCharges, dtype: float64

# %%
df.groupby('gender')['customerID'].count()
# Out:
# gender
# Female    3488
# Male      3555
# Name: customerID, dtype: int64

# %%
df.groupby('InternetService')['customerID'].count()
# Out:
# InternetService
# DSL            2421
# Fiber optic    3096
# No             1526
# Name: customerID, dtype: int64

# %%
df.groupby('InternetService')['TotalCharges'].sum().sort_values(ascending=False)
# Out:
# InternetService
# Fiber optic    9923622.95
# DSL            5121410.85
# No             1011134.90
# Name: TotalCharges, dtype: float64

# %%
df.groupby('Contract').agg(
    CustomerNo=('customerID', 'count'),
    TotalCharge=('TotalCharges', 'sum')
)
# Out:
#                 CustomerNo  TotalCharge
# Contract
# Month-to-month        3875    5305861.5
# One year              1473    4467053.5
# Two year              1695    6283253.7

# %%
df.groupby(['InternetService','Contract']).agg(customerNo=('customerID','count'),
TotalCharge=('TotalCharges','sum')).sort_values(by='TotalCharge', ascending=False)
# Out:
#                                 customerNo  TotalCharge
# InternetService Contract
# Fiber optic     Month-to-month        2128   4191552.55
#                 Two year               429   2931646.05
#                 One year               539   2800424.35
# DSL             Two year               628   2666283.80
#                 One year               570   1439990.85
#                 Month-to-month        1223   1015136.20
# No              Two year               638    685323.85
#                 One year               364    226638.30
#                 Month-to-month         524     99172.75
